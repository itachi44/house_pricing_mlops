# %% [markdown]
# # Summary
#
# Dans ce notebook, nous allons mettre en pratique les algorithmes de regression sur un jeu de données relatif aux prix de biens immobilliers à Ames, Iowa.
#
# Voici un résumé des **étapes du travail**:
#
#
# **Outils:**
# - **Collecte et exploration des données**: pandas, polar, missingno, ydata-profiling, seaborn, plotly, ...
# - **Modélisaion**: lazypredict sklearn, xgboost, lightgbm, catboost, yellowbricks, ...
# - **Optimisation des hyperparamètres**: gridsearch (sklearn), optuna, hyperopt, ...
# - **Déploiement**: mlflow, fastapi, evidently, heroku, pythonanywhere, azure webapp, ...

# %%
#!pip -q install missingno optuna pendulum loguru ydata_profiling yellowbrick mlflow xgboost tensorflow pycaret boto3

# %% [markdown]
# # Librairies

# %%
# reload modules before executing user code.
# %reload_ext autoreload
# %autoreload 2

import boto3
import os
import sys
import warnings
from pathlib import Path
from typing import Dict, Union

import dill
import matplotlib.pyplot as plt
import missingno as msno
import mlflow
import mlflow.sklearn
import numpy as np
import optuna
import pandas as pd
import plotly.express as px
import pendulum
import seaborn as sns
import boto3


from botocore.exceptions import NoCredentialsError
from loguru import logger
from mlflow.models import infer_signature
from sklearn import set_config
from sklearn.compose import ColumnTransformer, make_column_selector, TransformedTargetRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (r2_score,
                             mean_squared_error,
                             mean_absolute_percentage_error,
                             max_error,
                            )
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, OneHotEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
#from ydata_profiling import ProfileReport
from yellowbrick.regressor import ResidualsPlot
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV


sys.path.append(str(Path.cwd().parent))
from settings.params import (DATA_DIR_INPUT,
                             DATA_DIR_OUTPUT,
                             MODEL_PARAMS,
                             REPORT_DIR,
                             RUNS_DIR,
                             TIMEZONE,
                             MODEL_DIR,
                             MODEL_NAME
                            )
from src.make_dataset import load_data
from src.trainer import define_pipeline, eval_metrics,train_models
from src.optimizer import optimize_model
from src.utils import (filter_variables_by_completion_rate, 
                       remove_single_modality_categorical_variables,
                       split_dataset,
                       save_object_with_dill,
                       load_dataset
                      )

set_config(display="diagram", print_changed_only=False)
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Settings

# %%
# time in UTC
log_fmt = ("<green>{time:YYYY-MM-DD HH:mm:ss.SSS!UTC}</green> | <level>{level: <8}</level> | "
           "<cyan>{name}</cyan>:<cyan>{function}</cyan>:<cyan>{line}</cyan> - {message}"
          )
log_config = {
    "handlers": [
        {"sink": sys.stderr, "format": log_fmt},
    ],
}
logger.configure(**log_config)
# Out:
# [1]

# %%
EXECUTION_DATE = pendulum.now(tz=TIMEZONE)

logger.info(f"Execution date: {EXECUTION_DATE}")

logger.info(f"\nData input directory : {DATA_DIR_INPUT}\nData output directory: {DATA_DIR_OUTPUT}")


# model parameters
FEATURES = MODEL_PARAMS["FEATURES"]
TARGET_NAME = MODEL_PARAMS["TARGET"]
# Out:
# 2023-08-22 20:15:53.527 | INFO     | __main__:<module>:3 - Execution date: 2023-08-22T20:15:53.527250+00:00
# 2023-08-22 20:15:53.528 | INFO     | __main__:<module>:5 -
# Data input directory : /Users/ahmadou-bamba/Desktop/MLOPS_PROJECT/notebooks/data/input
# Data output directory: /Users/ahmadou-bamba/Desktop/MLOPS_PROJECT/notebooks/data/output

# %% [markdown]
# # Data Collection

# %%
data = load_dataset("cleaned_data")

# %%
data.head()
# Out:
#    mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour  \
# 0        60.0       RL         65.0   8450.0   Pave      Reg         Lvl
# 1        20.0       RL         80.0   9600.0   Pave      Reg         Lvl
# 2        60.0       RL         68.0  11250.0   Pave      IR1         Lvl
# 3        70.0       RL         60.0   9550.0   Pave      IR1         Lvl
# 4        60.0       RL         84.0  14260.0   Pave      IR1         Lvl
#
#   utilities lotconfig landslope neighborhood condition1 condition2 bldgtype  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
#   housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle  \
# 0     2Story          7.0          5.0     2003.0        2003.0     Gable
# 1     1Story          6.0          8.0     1976.0        1976.0     Gable
# 2     2Story          7.0          5.0     2001.0        2002.0     Gable
# 3     2Story          7.0          5.0     1915.0        1970.0     Gable
# 4     2Story          8.0          5.0     2000.0        2000.0     Gable
#
#   roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond  \
# 0  CompShg     VinylSd     VinylSd    BrkFace       196.0        Gd        TA
# 1  CompShg     MetalSd     MetalSd       None         0.0        TA        TA
# 2  CompShg     VinylSd     VinylSd    BrkFace       162.0        Gd        TA
# 3  CompShg     Wd Sdng     Wd Shng       None         0.0        TA        TA
# 4  CompShg     VinylSd     VinylSd    BrkFace       350.0        Gd        TA
#
#   foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1  \
# 0      PConc       Gd       TA           No          GLQ       706.0
# 1     CBlock       Gd       TA           Gd          ALQ       978.0
# 2      PConc       Gd       TA           Mn          GLQ       486.0
# 3     BrkTil       TA       Gd           No          ALQ       216.0
# 4      PConc       Gd       TA           Av          GLQ       655.0
#
#   bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc  \
# 0          Unf         0.0      150.0        856.0    GasA        Ex
# 1          Unf         0.0      284.0       1262.0    GasA        Ex
# 2          Unf         0.0      434.0        920.0    GasA        Ex
# 3          Unf         0.0      540.0        756.0    GasA        Gd
# 4          Unf         0.0      490.0       1145.0    GasA        Ex
#
#   centralair electrical  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  \
# 0          Y      SBrkr     856.0     854.0           0.0     1710.0
# 1          Y      SBrkr    1262.0       0.0           0.0     1262.0
# 2          Y      SBrkr     920.0     866.0           0.0     1786.0
# 3          Y      SBrkr     961.0     756.0           0.0     1717.0
# 4          Y      SBrkr    1145.0    1053.0           0.0     2198.0
#
#    bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr  \
# 0           1.0           0.0       2.0       1.0           3.0           1.0
# 1           0.0           1.0       2.0       0.0           3.0           1.0
# 2           1.0           0.0       2.0       1.0           3.0           1.0
# 3           1.0           0.0       1.0       0.0           3.0           1.0
# 4           1.0           0.0       2.0       1.0           4.0           1.0
#
#   kitchenqual  totrmsabvgrd functional  fireplaces fireplacequ garagetype  \
# 0          Gd           8.0        Typ         0.0        None     Attchd
# 1          TA           6.0        Typ         1.0          TA     Attchd
# 2          Gd           6.0        Typ         1.0          TA     Attchd
# 3          Gd           7.0        Typ         1.0          Gd     Detchd
# 4          Gd           9.0        Typ         1.0          TA     Attchd
#
#    garageyrblt garagefinish  garagecars  garagearea garagequal garagecond  \
# 0       2003.0          RFn         2.0       548.0         TA         TA
# 1       1976.0          RFn         2.0       460.0         TA         TA
# 2       2001.0          RFn         2.0       608.0         TA         TA
# 3       1998.0          Unf         3.0       642.0         TA         TA
# 4       2000.0          RFn         3.0       836.0         TA         TA
#
#   paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  \
# 0          Y         0.0         61.0            0.0        0.0          0.0
# 1          Y       298.0          0.0            0.0        0.0          0.0
# 2          Y         0.0         42.0            0.0        0.0          0.0
# 3          Y         0.0         35.0          272.0        0.0          0.0
# 4          Y       192.0         84.0            0.0        0.0          0.0
#
#    poolarea  miscval  mosold  yrsold saletype salecondition  saleprice  \
# 0       0.0      0.0     2.0  2008.0       WD        Normal   208500.0
# 1       0.0      0.0     5.0  2007.0       WD        Normal   181500.0
# 2       0.0      0.0     9.0  2008.0       WD        Normal   223500.0
# 3       0.0      0.0     2.0  2006.0       WD       Abnorml   140000.0
# 4       0.0      0.0    12.0  2008.0       WD        Normal   250000.0
#
#    building_age  remodel_age
# 0           5.0          5.0
# 1          31.0         31.0
# 2           7.0          6.0
# 3          91.0         36.0
# 4           8.0          8.0

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Train / test split

# %%
X_train, X_test, y_train, y_test = split_dataset(data)
# Out:
# 2023-08-22 20:15:53.985 | INFO     | src.utils:split_dataset:96 -
# x train: (1168, 20)
# Y train: (1168,)
# X test: (292, 20)
# Y test: (292,)

# %%
categorical_features = data.select_dtypes(include="object").columns
#print(f"Categorical features:\n {categorical_features}\n")

numerical_features = data.select_dtypes(include="number").columns
#print(f"Numerical features:\n {numerical_features}")

# %%
#numerical_features=numerical_features.drop('id')
numerical_features=numerical_features.drop('saleprice')

# %% [markdown]
# ## Pipeline-modeling-training

# %%
ec2_user = os.getenv("MLFLOW_SERVER_USERNAME")
ec2_pwd = os.getenv("MLFLOW_SERVER_PASSWORD")
os.environ['AWS_ACCESS_KEY_ID'] = 'AKIAZDXC42LPILEJCGNG'
os.environ['AWS_SECRET_ACCESS_KEY'] = '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'

# %%
tracking_uri = "http://{0}:{1}@ec2-user@ec2-3-253-117-137.eu-west-1.compute.amazonaws.com:5000".format(ec2_user,ec2_pwd)

# %%
mlflow.set_tracking_uri(tracking_uri)

# %%
exp_name = "house-pricing"
experiment = mlflow.get_experiment_by_name(exp_name)
artifact_path = "model"
if not experiment:
    experiment_id = mlflow.create_experiment(exp_name, s3_bucket)
else:
    experiment_id = experiment.experiment_id

# %%
mlflow.autolog()
# Out:
# 2023/08/22 22:15:56 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2023/08/22 22:15:56 INFO mlflow.tracking.fluent: Autologging successfully enabled for statsmodels.
# 2023/08/22 22:15:56 INFO mlflow.tracking.fluent: Autologging successfully enabled for tensorflow.

# %%
model_results = train_models(
    data, 
    X_train, 
    y_train, 
    X_test, 
    y_test, 
    categorical_features,
    numerical_features,
    artifact_path,
    experiment_id,
    target_transformer=False
)
# Out:
# 2023-08-22 20:15:57.499 | INFO     | src.trainer:define_pipeline:97 - Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('simpleimputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
#                                                                                  verbose=0)),
#                                                                   ('robustscaler',
#                                                                    RobustScaler(copy=True...
#                                                                                  drop='if_binary',
#                                                                                  dtype=<class 'numpy.float64'>,
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=True))],
#                                                            verbose=False),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fd665517760>)],
#                                    verbose=False,
#                                    verbose_feature_names_out=False)),
#                 ('estimator',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize='deprecated', positive=False))],
#          verbose=False)
# 2023/08/22 22:15:57 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `[('preprocessor', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                           ...`
# 2023/08/22 22:15:57 WARNING mlflow.utils: Truncated the value of the key `preprocessor`. Truncated value: `ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                                             ...`
# 2023/08/22 22:15:57 WARNING mlflow.utils: Truncated the value of the key `preprocessor__transformers`. Truncated value: `[('num', Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                missing_values=nan, strategy='median',
#                                verbose=0)),
#                 ('robustscaler',
#                  RobustScaler(copy=True, quantile_range=(25.0, 75.0),
#                               unit_variance=False, with_centering=True,
#                               with_scaling=True))],
#          ve...`
# 2023/08/22 22:15:57 WARNING mlflow.utils: Truncated the value of the key `preprocessor__cat`. Truncated value: `Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True,
#                                fill_value='undefined', missing_values=nan,
#                                strategy='constant', verbose=0)),
#                 ('onehotencoder',
#                  OneHotEncoder(categories='auto', drop='if_binary',
#                                dtype=<class 'numpy.float64'>,
#                                handle_unknown='ignore', sparse=True))],
#   ...`
# 2023/08/22 22:15:57 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023/08/22 22:16:07 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# 2023/08/22 22:16:08 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 2023/08/22 22:16:09 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023-08-22 20:16:09.470 | INFO     | src.trainer:train_models:151 - Model: LinearRegression
# 2023-08-22 20:16:09.471 | INFO     | src.trainer:train_models:152 - run_id: 5fb61144eced4379a3078a58e53beb43
# 2023-08-22 20:16:09.472 | INFO     | src.trainer:train_models:153 - version tag value: v1
# 2023-08-22 20:16:09.473 | INFO     | src.trainer:train_models:154 - --
# 2023-08-22 20:16:10.090 | INFO     | src.trainer:train_models:155 - default artifacts URI: 's3://mlflow010/5fb61144eced4379a3078a58e53beb43/artifacts'
# 2023-08-22 20:16:10.090 | INFO     | src.trainer:train_models:156 - Train: {'rmse': 36410.10552514463, 'mae': 22319.738710703285, 'r2': 0.7996120276150427, 'max_error': 514087.1837477549}
# 2023-08-22 20:16:10.091 | INFO     | src.trainer:train_models:157 - Test: {'rmse': 29546.5868377435, 'mae': 22713.028277810656, 'r2': 0.826853355865427, 'max_error': 120920.51953596156}
# 2023/08/22 22:16:21 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under s3://mlflow010/5fb61144eced4379a3078a58e53beb43/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# Registered model 'LinearRegressionModel' already exists. Creating a new version of this model...
# 2023/08/22 22:16:23 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: LinearRegressionModel, version 4
# Created version '4' of model 'LinearRegressionModel'.
# 2023-08-22 20:16:26.024 | INFO     | src.trainer:define_pipeline:97 - Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('simpleimputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
#                                                                                  verbose=0)),
#                                                                   ('robustscaler',
#                                                                    RobustScaler(copy=True...
#                 ('estimator',
#                  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                        criterion='squared_error',
#                                        max_depth=None, max_features='auto',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=10, n_jobs=None,
#                                        oob_score=False, random_state=None,
#                                        verbose=0, warm_start=False))],
#          verbose=False)
# 2023/08/22 22:16:26 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `[('preprocessor', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                           ...`
# 2023/08/22 22:16:26 WARNING mlflow.utils: Truncated the value of the key `preprocessor`. Truncated value: `ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                                             ...`
# 2023/08/22 22:16:26 WARNING mlflow.utils: Truncated the value of the key `preprocessor__transformers`. Truncated value: `[('num', Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                missing_values=nan, strategy='median',
#                                verbose=0)),
#                 ('robustscaler',
#                  RobustScaler(copy=True, quantile_range=(25.0, 75.0),
#                               unit_variance=False, with_centering=True,
#                               with_scaling=True))],
#          ve...`
# 2023/08/22 22:16:26 WARNING mlflow.utils: Truncated the value of the key `preprocessor__cat`. Truncated value: `Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True,
#                                fill_value='undefined', missing_values=nan,
#                                strategy='constant', verbose=0)),
#                 ('onehotencoder',
#                  OneHotEncoder(categories='auto', drop='if_binary',
#                                dtype=<class 'numpy.float64'>,
#                                handle_unknown='ignore', sparse=True))],
#   ...`
# 2023/08/22 22:16:26 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023/08/22 22:16:39 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 2023/08/22 22:16:39 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023-08-22 20:16:39.987 | INFO     | src.trainer:train_models:151 - Model: RandomForest
# 2023-08-22 20:16:39.988 | INFO     | src.trainer:train_models:152 - run_id: 1e855d674bc24e27b969d44cc6a155f0
# 2023-08-22 20:16:39.989 | INFO     | src.trainer:train_models:153 - version tag value: v1
# 2023-08-22 20:16:39.990 | INFO     | src.trainer:train_models:154 - --
# 2023-08-22 20:16:40.206 | INFO     | src.trainer:train_models:155 - default artifacts URI: 's3://mlflow010/1e855d674bc24e27b969d44cc6a155f0/artifacts'
# 2023-08-22 20:16:40.207 | INFO     | src.trainer:train_models:156 - Train: {'rmse': 15351.950811982224, 'mae': 9267.995662100457, 'r2': 0.9643749964625764, 'max_error': 125975.0}
# 2023-08-22 20:16:40.207 | INFO     | src.trainer:train_models:157 - Test: {'rmse': 26649.378791438958, 'mae': 19757.64931506849, 'r2': 0.8591445615489602, 'max_error': 108200.0}
# 2023/08/22 22:16:49 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under s3://mlflow010/1e855d674bc24e27b969d44cc6a155f0/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# Registered model 'RandomForestModel' already exists. Creating a new version of this model...
# 2023/08/22 22:16:50 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestModel, version 15
# Created version '15' of model 'RandomForestModel'.
# 2023-08-22 20:16:50.386 | INFO     | src.trainer:define_pipeline:97 - Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('simpleimputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
#                                                                                  verbose=0)),
#                                                                   ('robustscaler',
#                                                                    RobustScaler(copy=True...
#                                            criterion='friedman_mse', init=None,
#                                            learning_rate=0.1,
#                                            loss='squared_error', max_depth=3,
#                                            max_features=None,
#                                            max_leaf_nodes=None,
#                                            min_impurity_decrease=0.0,
#                                            min_samples_leaf=1,
#                                            min_samples_split=2,
#                                            min_weight_fraction_leaf=0.0,
#                                            n_estimators=10,
#                                            n_iter_no_change=None,
#                                            random_state=None, subsample=1.0,
#                                            tol=0.0001, validation_fraction=0.1,
#                                            verbose=0, warm_start=False))],
#          verbose=False)
# 2023/08/22 22:16:50 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `[('preprocessor', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                           ...`
# 2023/08/22 22:16:50 WARNING mlflow.utils: Truncated the value of the key `preprocessor`. Truncated value: `ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                                             ...`
# 2023/08/22 22:16:50 WARNING mlflow.utils: Truncated the value of the key `estimator`. Truncated value: `GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='squared_error',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=10, n_iter_no_change=None,
#                           random_state=None, s...`
# 2023/08/22 22:16:50 WARNING mlflow.utils: Truncated the value of the key `preprocessor__transformers`. Truncated value: `[('num', Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                missing_values=nan, strategy='median',
#                                verbose=0)),
#                 ('robustscaler',
#                  RobustScaler(copy=True, quantile_range=(25.0, 75.0),
#                               unit_variance=False, with_centering=True,
#                               with_scaling=True))],
#          ve...`
# 2023/08/22 22:16:50 WARNING mlflow.utils: Truncated the value of the key `preprocessor__cat`. Truncated value: `Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True,
#                                fill_value='undefined', missing_values=nan,
#                                strategy='constant', verbose=0)),
#                 ('onehotencoder',
#                  OneHotEncoder(categories='auto', drop='if_binary',
#                                dtype=<class 'numpy.float64'>,
#                                handle_unknown='ignore', sparse=True))],
#   ...`
# 2023/08/22 22:16:50 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023/08/22 22:16:55 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 2023/08/22 22:16:55 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023-08-22 20:16:55.989 | INFO     | src.trainer:train_models:151 - Model: GradientBoosting
# 2023-08-22 20:16:55.990 | INFO     | src.trainer:train_models:152 - run_id: 6ff3c9307012400db58e674bebc6091a
# 2023-08-22 20:16:55.991 | INFO     | src.trainer:train_models:153 - version tag value: v1
# 2023-08-22 20:16:55.992 | INFO     | src.trainer:train_models:154 - --
# 2023-08-22 20:16:56.454 | INFO     | src.trainer:train_models:155 - default artifacts URI: 's3://mlflow010/6ff3c9307012400db58e674bebc6091a/artifacts'
# 2023-08-22 20:16:56.454 | INFO     | src.trainer:train_models:156 - Train: {'rmse': 46085.0315137492, 'mae': 31662.62326456293, 'r2': 0.6789685700228276, 'max_error': 367874.59311958746}
# 2023-08-22 20:16:56.455 | INFO     | src.trainer:train_models:157 - Test: {'rmse': 40145.52182316525, 'mae': 30655.853107624855, 'r2': 0.6803507757454754, 'max_error': 151109.82026537543}
# 2023/08/22 22:17:02 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under s3://mlflow010/6ff3c9307012400db58e674bebc6091a/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# Registered model 'GradientBoostingModel' already exists. Creating a new version of this model...
# 2023/08/22 22:17:02 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: GradientBoostingModel, version 2
# Created version '2' of model 'GradientBoostingModel'.

# %%
model_with_transformer_results = train_models(
    data, 
    X_train, 
    y_train, 
    X_test, 
    y_test, 
    categorical_features,
    numerical_features,
    artifact_path,
    experiment_id,
    target_transformer=True
)
# Out:
# 2023-08-22 20:17:03.766 | INFO     | src.trainer:define_pipeline:97 - Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('simpleimputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
#                                                                                  verbose=0)),
#                                                                   ('robustscaler',
#                                                                    RobustScaler(copy=True...
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fd6653cb550>)],
#                                    verbose=False,
#                                    verbose_feature_names_out=False)),
#                 ('estimator',
#                  TransformedTargetRegressor(check_inverse=True,
#                                             func=<ufunc 'log'>,
#                                             inverse_func=<ufunc 'exp'>,
#                                             regressor=LinearRegression(copy_X=True,
#                                                                        fit_intercept=True,
#                                                                        n_jobs=None,
#                                                                        normalize='deprecated',
#                                                                        positive=False),
#                                             transformer=None))],
#          verbose=False)
# 2023/08/22 22:17:03 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `[('preprocessor', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                           ...`
# 2023/08/22 22:17:03 WARNING mlflow.utils: Truncated the value of the key `preprocessor`. Truncated value: `ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                                             ...`
# 2023/08/22 22:17:03 WARNING mlflow.utils: Truncated the value of the key `estimator`. Truncated value: `TransformedTargetRegressor(check_inverse=True, func=<ufunc 'log'>,
#                            inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression(copy_X=True,
#                                                       fit_intercept=True,
#                                                       n_jobs=None,
#                                                       normalize='deprecated',
#                                                       positive=False),
#                   ...`
# 2023/08/22 22:17:03 WARNING mlflow.utils: Truncated the value of the key `preprocessor__transformers`. Truncated value: `[('num', Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                missing_values=nan, strategy='median',
#                                verbose=0)),
#                 ('robustscaler',
#                  RobustScaler(copy=True, quantile_range=(25.0, 75.0),
#                               unit_variance=False, with_centering=True,
#                               with_scaling=True))],
#          ve...`
# 2023/08/22 22:17:03 WARNING mlflow.utils: Truncated the value of the key `preprocessor__cat`. Truncated value: `Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True,
#                                fill_value='undefined', missing_values=nan,
#                                strategy='constant', verbose=0)),
#                 ('onehotencoder',
#                  OneHotEncoder(categories='auto', drop='if_binary',
#                                dtype=<class 'numpy.float64'>,
#                                handle_unknown='ignore', sparse=True))],
#   ...`
# 2023/08/22 22:17:03 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023/08/22 22:17:17 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 2023/08/22 22:17:17 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023-08-22 20:17:19.853 | INFO     | src.trainer:train_models:151 - Model: LinearRegression
# 2023-08-22 20:17:19.854 | INFO     | src.trainer:train_models:152 - run_id: f284e065d11d4586b958496de18b4e3b
# 2023-08-22 20:17:19.855 | INFO     | src.trainer:train_models:153 - version tag value: v1
# 2023-08-22 20:17:19.856 | INFO     | src.trainer:train_models:154 - --
# 2023-08-22 20:17:20.098 | INFO     | src.trainer:train_models:155 - default artifacts URI: 's3://mlflow010/f284e065d11d4586b958496de18b4e3b/artifacts'
# 2023-08-22 20:17:20.099 | INFO     | src.trainer:train_models:156 - Train: {'rmse': 46590.163952345385, 'mae': 20821.966861990466, 'r2': 0.6718924279285152, 'max_error': 1208155.0889966583}
# 2023-08-22 20:17:20.099 | INFO     | src.trainer:train_models:157 - Test: {'rmse': 26560.806990463974, 'mae': 19418.81318247887, 'r2': 0.8600792991019943, 'max_error': 140966.15195289956}
# 2023/08/22 22:19:36 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under s3://mlflow010/f284e065d11d4586b958496de18b4e3b/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# Registered model 'LinearRegressionModel' already exists. Creating a new version of this model...
# 2023/08/22 22:19:37 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: LinearRegressionModel, version 5
# Created version '5' of model 'LinearRegressionModel'.
# 2023-08-22 20:19:37.901 | INFO     | src.trainer:define_pipeline:97 - Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('simpleimputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
#                                                                                  verbose=0)),
#                                                                   ('robustscaler',
#                                                                    RobustScaler(copy=True...
#                                             regressor=RandomForestRegressor(bootstrap=True,
#                                                                             ccp_alpha=0.0,
#                                                                             criterion='squared_error',
#                                                                             max_depth=None,
#                                                                             max_features='auto',
#                                                                             max_leaf_nodes=None,
#                                                                             max_samples=None,
#                                                                             min_impurity_decrease=0.0,
#                                                                             min_samples_leaf=1,
#                                                                             min_samples_split=2,
#                                                                             min_weight_fraction_leaf=0.0,
#                                                                             n_estimators=10,
#                                                                             n_jobs=None,
#                                                                             oob_score=False,
#                                                                             random_state=None,
#                                                                             verbose=0,
#                                                                             warm_start=False),
#                                             transformer=None))],
#          verbose=False)
# 2023/08/22 22:19:37 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `[('preprocessor', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                           ...`
# 2023/08/22 22:19:37 WARNING mlflow.utils: Truncated the value of the key `preprocessor`. Truncated value: `ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                                             ...`
# 2023/08/22 22:19:37 WARNING mlflow.utils: Truncated the value of the key `estimator`. Truncated value: `TransformedTargetRegressor(check_inverse=True, func=<ufunc 'log'>,
#                            inverse_func=<ufunc 'exp'>,
#                            regressor=RandomForestRegressor(bootstrap=True,
#                                                            ccp_alpha=0.0,
#                                                            criterion='squared_error',
#                                                            max_depth=None,
#                                                            max_fe...`
# 2023/08/22 22:19:37 WARNING mlflow.utils: Truncated the value of the key `preprocessor__transformers`. Truncated value: `[('num', Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                missing_values=nan, strategy='median',
#                                verbose=0)),
#                 ('robustscaler',
#                  RobustScaler(copy=True, quantile_range=(25.0, 75.0),
#                               unit_variance=False, with_centering=True,
#                               with_scaling=True))],
#          ve...`
# 2023/08/22 22:19:37 WARNING mlflow.utils: Truncated the value of the key `preprocessor__cat`. Truncated value: `Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True,
#                                fill_value='undefined', missing_values=nan,
#                                strategy='constant', verbose=0)),
#                 ('onehotencoder',
#                  OneHotEncoder(categories='auto', drop='if_binary',
#                                dtype=<class 'numpy.float64'>,
#                                handle_unknown='ignore', sparse=True))],
#   ...`
# 2023/08/22 22:19:37 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023/08/22 22:19:44 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 2023/08/22 22:19:44 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023-08-22 20:19:44.520 | INFO     | src.trainer:train_models:151 - Model: RandomForest
# 2023-08-22 20:19:44.521 | INFO     | src.trainer:train_models:152 - run_id: 07000a3b0cc54b8ab945bd0d5232ca50
# 2023-08-22 20:19:44.522 | INFO     | src.trainer:train_models:153 - version tag value: v1
# 2023-08-22 20:19:44.523 | INFO     | src.trainer:train_models:154 - --
# 2023-08-22 20:19:44.845 | INFO     | src.trainer:train_models:155 - default artifacts URI: 's3://mlflow010/07000a3b0cc54b8ab945bd0d5232ca50/artifacts'
# 2023-08-22 20:19:44.846 | INFO     | src.trainer:train_models:156 - Train: {'rmse': 14719.883311422936, 'mae': 8421.127475851947, 'r2': 0.9672480991825624, 'max_error': 125782.67973907443}
# 2023-08-22 20:19:44.846 | INFO     | src.trainer:train_models:157 - Test: {'rmse': 26569.516036382833, 'mae': 19171.354932266353, 'r2': 0.8599875266201196, 'max_error': 112438.08824016832}
# 2023/08/22 22:20:04 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under s3://mlflow010/07000a3b0cc54b8ab945bd0d5232ca50/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# Registered model 'RandomForestModel' already exists. Creating a new version of this model...
# 2023/08/22 22:20:09 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestModel, version 16
# Created version '16' of model 'RandomForestModel'.
# 2023-08-22 20:20:10.346 | INFO     | src.trainer:define_pipeline:97 - Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('simpleimputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
#                                                                                  verbose=0)),
#                                                                   ('robustscaler',
#                                                                    RobustScaler(copy=True...
#                                                                                 learning_rate=0.1,
#                                                                                 loss='squared_error',
#                                                                                 max_depth=3,
#                                                                                 max_features=None,
#                                                                                 max_leaf_nodes=None,
#                                                                                 min_impurity_decrease=0.0,
#                                                                                 min_samples_leaf=1,
#                                                                                 min_samples_split=2,
#                                                                                 min_weight_fraction_leaf=0.0,
#                                                                                 n_estimators=10,
#                                                                                 n_iter_no_change=None,
#                                                                                 random_state=None,
#                                                                                 subsample=1.0,
#                                                                                 tol=0.0001,
#                                                                                 validation_fraction=0.1,
#                                                                                 verbose=0,
#                                                                                 warm_start=False),
#                                             transformer=None))],
#          verbose=False)
# 2023/08/22 22:20:10 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `[('preprocessor', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                           ...`
# 2023/08/22 22:20:10 WARNING mlflow.utils: Truncated the value of the key `preprocessor`. Truncated value: `ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('simpleimputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                                             ...`
# 2023/08/22 22:20:10 WARNING mlflow.utils: Truncated the value of the key `estimator`. Truncated value: `TransformedTargetRegressor(check_inverse=True, func=<ufunc 'log'>,
#                            inverse_func=<ufunc 'exp'>,
#                            regressor=GradientBoostingRegressor(alpha=0.9,
#                                                                ccp_alpha=0.0,
#                                                                criterion='friedman_mse',
#                                                                init=None,
#                                                             ...`
# 2023/08/22 22:20:10 WARNING mlflow.utils: Truncated the value of the key `preprocessor__transformers`. Truncated value: `[('num', Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                missing_values=nan, strategy='median',
#                                verbose=0)),
#                 ('robustscaler',
#                  RobustScaler(copy=True, quantile_range=(25.0, 75.0),
#                               unit_variance=False, with_centering=True,
#                               with_scaling=True))],
#          ve...`
# 2023/08/22 22:20:10 WARNING mlflow.utils: Truncated the value of the key `preprocessor__cat`. Truncated value: `Pipeline(memory=None,
#          steps=[('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True,
#                                fill_value='undefined', missing_values=nan,
#                                strategy='constant', verbose=0)),
#                 ('onehotencoder',
#                  OneHotEncoder(categories='auto', drop='if_binary',
#                                dtype=<class 'numpy.float64'>,
#                                handle_unknown='ignore', sparse=True))],
#   ...`
# 2023/08/22 22:20:10 WARNING mlflow.utils: Truncated the value of the key `estimator__regressor`. Truncated value: `GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='squared_error',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=10, n_iter_no_change=None,
#                           random_state=None, s...`
# 2023/08/22 22:20:10 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023/08/22 22:20:20 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 2023/08/22 22:20:21 WARNING mlflow.data.pandas_dataset: Failed to infer schema for Pandas dataset. Exception: Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float).
# 2023-08-22 20:20:22.613 | INFO     | src.trainer:train_models:151 - Model: GradientBoosting
# 2023-08-22 20:20:22.614 | INFO     | src.trainer:train_models:152 - run_id: 0680f3e9e30140b88be9af85a1f95ec8
# 2023-08-22 20:20:22.615 | INFO     | src.trainer:train_models:153 - version tag value: v1
# 2023-08-22 20:20:22.616 | INFO     | src.trainer:train_models:154 - --
# 2023-08-22 20:20:22.991 | INFO     | src.trainer:train_models:155 - default artifacts URI: 's3://mlflow010/0680f3e9e30140b88be9af85a1f95ec8/artifacts'
# 2023-08-22 20:20:22.992 | INFO     | src.trainer:train_models:156 - Train: {'rmse': 51355.10265433455, 'mae': 31668.180330759056, 'r2': 0.6013470529184028, 'max_error': 456864.1660949373}
# 2023-08-22 20:20:22.993 | INFO     | src.trainer:train_models:157 - Test: {'rmse': 41656.99418017475, 'mae': 29615.243399228453, 'r2': 0.6558281872530622, 'max_error': 182010.13371275336}
# 2023/08/22 22:20:41 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under s3://mlflow010/0680f3e9e30140b88be9af85a1f95ec8/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# Registered model 'GradientBoostingModel' already exists. Creating a new version of this model...
# 2023/08/22 22:20:41 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: GradientBoostingModel, version 3
# Created version '3' of model 'GradientBoostingModel'.

# %% [markdown]
# ## Model évaluation

# %%
model_results
# Out:
# {'LinearRegression': {'train_metrics': {'rmse': 36410.10552514463,
#    'mae': 22319.738710703285,
#    'r2': 0.7996120276150427,
#    'max_error': 514087.1837477549},
#   'test_metrics': {'rmse': 29546.5868377435,
#    'mae': 22713.028277810656,
#    'r2': 0.826853355865427,
#    'max_error': 120920.51953596156},
#   'run_id': '5fb61144eced4379a3078a58e53beb43'},
#  'RandomForest': {'train_metrics': {'rmse': 15351.950811982224,
#    'mae': 9267.995662100457,
#    'r2': 0.9643749964625764,
#    'max_error': 125975.0},
#   'test_metrics': {'rmse': 26649.378791438958,
#    'mae': 19757.64931506849,
#    'r2': 0.8591445615489602,
#    'max_error': 108200.0},
#   'run_id': '1e855d674bc24e27b969d44cc6a155f0'},
#  'GradientBoosting': {'train_metrics': {'rmse': 46085.0315137492,
#    'mae': 31662.62326456293,
#    'r2': 0.6789685700228276,
#    'max_error': 367874.59311958746},
#   'test_metrics': {'rmse': 40145.52182316525,
#    'mae': 30655.853107624855,
#    'r2': 0.6803507757454754,
#    'max_error': 151109.82026537543},
#   'run_id': '6ff3c9307012400db58e674bebc6091a'}}

# %%
model_with_transformer_results
# Out:
# {'LinearRegression': {'train_metrics': {'rmse': 46590.163952345385,
#    'mae': 20821.966861990466,
#    'r2': 0.6718924279285152,
#    'max_error': 1208155.0889966583},
#   'test_metrics': {'rmse': 26560.806990463974,
#    'mae': 19418.81318247887,
#    'r2': 0.8600792991019943,
#    'max_error': 140966.15195289956},
#   'run_id': 'f284e065d11d4586b958496de18b4e3b'},
#  'RandomForest': {'train_metrics': {'rmse': 14719.883311422936,
#    'mae': 8421.127475851947,
#    'r2': 0.9672480991825624,
#    'max_error': 125782.67973907443},
#   'test_metrics': {'rmse': 26569.516036382833,
#    'mae': 19171.354932266353,
#    'r2': 0.8599875266201196,
#    'max_error': 112438.08824016832},
#   'run_id': '07000a3b0cc54b8ab945bd0d5232ca50'},
#  'GradientBoosting': {'train_metrics': {'rmse': 51355.10265433455,
#    'mae': 31668.180330759056,
#    'r2': 0.6013470529184028,
#    'max_error': 456864.1660949373},
#   'test_metrics': {'rmse': 41656.99418017475,
#    'mae': 29615.243399228453,
#    'r2': 0.6558281872530622,
#    'max_error': 182010.13371275336},
#   'run_id': '0680f3e9e30140b88be9af85a1f95ec8'}}

# %%
for model_name, metrics_dict in model_results.items():
    print(f"Model: {model_name}")
    print("Train Metrics:")
    for metric_name, metric_value in metrics_dict["train_metrics"].items():
        print(f"  {metric_name}: {metric_value:.4f}")
    print("Test Metrics:")
    for metric_name, metric_value in metrics_dict["test_metrics"].items():
        print(f"  {metric_name}: {metric_value:.4f}")
    print("\n")
# Out:
# Model: LinearRegression
# Train Metrics:
#   rmse: 36410.1055
#   mae: 22319.7387
#   r2: 0.7996
#   max_error: 514087.1837
# Test Metrics:
#   rmse: 29546.5868
#   mae: 22713.0283
#   r2: 0.8269
#   max_error: 120920.5195
#
#
# Model: RandomForest
# Train Metrics:
#   rmse: 15351.9508
#   mae: 9267.9957
#   r2: 0.9644
#   max_error: 125975.0000
# Test Metrics:
#   rmse: 26649.3788
#   mae: 19757.6493
#   r2: 0.8591
#   max_error: 108200.0000
#
#
# Model: GradientBoosting
# Train Metrics:
#   rmse: 46085.0315
#   mae: 31662.6233
#   r2: 0.6790
#   max_error: 367874.5931
# Test Metrics:
#   rmse: 40145.5218
#   mae: 30655.8531
#   r2: 0.6804
#   max_error: 151109.8203

# %% [markdown]
# ## Tuning

# %%
rf_model_run_id = model_results['RandomForest']['run_id']
best_model = mlflow.sklearn.load_model(f"runs:/{rf_model_run_id}/model")

# %%
param_dist = {
    "estimator__n_estimators": [10, 15, 20, 25, 30, 40],
    "estimator__max_depth": [None, 10, 20, 30, 35, 40],
    "estimator__min_samples_split": [2, 3, 4, 5, 10]
}

# %%
best_estimator, best_params = optimize_model(
    X_train, 
    y_train, 
    best_model, 
    param_dist, 
    n_iter=100, 
    cv=3, 
    random_state=42, 
    n_jobs=-1
)
# Out:
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [3, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/ahmadou-bamba/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [1, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 2023/08/23 12:43:03 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: INVALID_PARAMETER_VALUE: The experiment 0 must be in the 'active' state. Current state is deleted.
# 2023/08/23 12:43:04 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: INVALID_PARAMETER_VALUE: The experiment 0 must be in the 'active' state. Current state is deleted.
# Best Parameters: {'estimator__n_estimators': 30, 'estimator__min_samples_split': 4, 'estimator__max_depth': None}
# Test Metrics for Optimized Model:
#   rmse: 26277.0559
#   mae: 18592.1340
#   r2: 0.8631
#   max_error: 113246.7520

# %% [markdown]
# ## Best Model performances

# %%
# Evaluate the best estimator on the test set
y_test_pred = best_estimator.predict(X_test)
test_metrics = eval_metrics(y_test, y_test_pred)

# Print the best parameters and test metrics
print("Best Parameters:", best_params)
print("Test Metrics for Optimized Model:")
for metric_name, metric_value in test_metrics.items():
    print(f"  {metric_name}: {metric_value:.4f}")
# Out:
# Best Parameters: {'estimator__n_estimators': 30, 'estimator__min_samples_split': 4, 'estimator__max_depth': None}
# Test Metrics for Optimized Model:
#   rmse: 26277.0559
#   mae: 18592.1340
#   r2: 0.8631
#   max_error: 113246.7520

# %% [markdown]
# ## Déploiement

# %%
# sauvargade du modèle en local: dill
model_path_name = Path(MODEL_DIR, f'{EXECUTION_DATE.strftime("%Y%m%d")}-{MODEL_NAME}')
logger.info(f"Best model path: {model_path_name}")
save_object_with_dill(object_to_save=best_estimator, object_path=model_path_name)
# Out:
# 2023-08-23 11:31:44.578 | INFO     | __main__:<module>:3 - Best model path: /Users/ahmadou-bamba/Desktop/MLOPS_PROJECT/notebooks/models/20230822-model_house_pricing.dill

# %%
# Set your AWS credentials if not already configured
aws_access_key = os.getenv('AWS_ACCESS_KEY_ID')
aws_secret_key = os.getenv('AWS_SECRET_ACCESS_KEY')

# Create a Boto3 S3 client
s3_client = boto3.client("s3", aws_access_key_id=aws_access_key, aws_secret_access_key=aws_secret_key)

# Define the S3 bucket name and the destination path
s3_bucket_name = "mlflow010"
s3_destination_path = "best_model/"

# Upload the saved model to S3
try:
    s3_client.upload_file(str(model_path_name), s3_bucket_name, s3_destination_path + "best_model.dill")
    print("Upload successful")
except FileNotFoundError:
    print("The file was not found")
except NoCredentialsError:
    print("Credentials not available")
# Out:
# Upload successful
